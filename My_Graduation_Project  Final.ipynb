# %% [markdown]
# ## My Graduation Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Supermarket.csv')
df
# Out:
#      Unnamed: 0   Invoice ID       Branch   City Customer type  Gender  \
# 0             0  750-67-8428    Helioples  Cairo        Member  Female
# 1             1  226-31-3081      mamoura   Alex        Normal  Female
# 2             2  631-41-3108    Helioples  Cairo        Normal    Male
# 3             3  123-19-1176    Helioples  Cairo        Member    Male
# 4             4  373-73-7910    Helioples  Cairo        Normal    Male
# ..          ...          ...          ...    ...           ...     ...
# 995         995  233-67-5758      mamoura   Alex        Normal    Male
# 996         996  303-96-2227  zouni beach  Gouna        Normal  Female
# 997         997  727-02-1313    Helioples  Cairo        Member    Male
# 998         998  347-56-2442    Helioples  Cairo        Normal    Male
# 999         999  849-09-3807    Helioples  Cairo        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0   Invoice ID     Branch   City Customer type  Gender  \
# 0           0  750-67-8428  Helioples  Cairo        Member  Female
# 1           1  226-31-3081    mamoura   Alex        Normal  Female
# 2           2  631-41-3108  Helioples  Cairo        Normal    Male
# 3           3  123-19-1176  Helioples  Cairo        Member    Male
# 4           4  373-73-7910  Helioples  Cairo        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %%
df.sample(5)
# Out:
#      Unnamed: 0   Invoice ID       Branch   City Customer type  Gender  \
# 883         883  291-55-6563    Helioples  Cairo        Member  Female
# 78           78  829-49-1914      mamoura   Alex        Member  Female
# 32           32  640-49-2076  zouni beach  Gouna        Normal    Male
# 689         689  305-03-2383    Helioples  Cairo        Normal  Female
# 807         807  257-60-7754    Helioples  Cairo        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 883      Home and lifestyle       34.42         6  10.326  216.846  3/30/2019
# 78       Food and beverages       78.31        10  39.155  822.255   3/5/2019
# 32        Sports and travel       83.78         8  33.512  703.752  1/10/2019
# 689      Food and beverages       67.10         3  10.065  211.365  2/15/2019
# 807  Electronic accessories       50.23         4  10.046  210.966   1/8/2019
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   Invoice ID               1000 non-null   object
#  2   Branch                   1000 non-null   object
#  3   City                     1000 non-null   object
#  4   Customer type            1000 non-null   object
#  5   Gender                   1000 non-null   object
#  6   Product line             1000 non-null   object
#  7   Unit price               1000 non-null   float64
#  8   Quantity                 1000 non-null   int64
#  9   Tax 5%                   1000 non-null   float64
#  10  Total                    1000 non-null   float64
#  11  Date                     1000 non-null   object
#  12  Time                     1000 non-null   object
#  13  Payment                  1000 non-null   object
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     9
# float64    7
# int64      2
# Name: count, dtype: int64

# %% [markdown]
# ## check missing data

# %%
df.isnull().any()
# Out:
# Unnamed: 0                 False
# Invoice ID                 False
# Branch                     False
# City                       False
# Customer type              False
# Gender                     False
# Product line               False
# Unit price                 False
# Quantity                   False
# Tax 5%                     False
# Total                      False
# Date                       False
# Time                       False
# Payment                    False
# cogs                       False
# gross margin percentage    False
# gross income               False
# Rating                     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ## 1) What is value count of Branch?
#
# the number of brancg appears on the dataset

# %%
df['Branch'].value_counts()
# Out:
# Branch
# Helioples      340
# zouni beach    332
# mamoura        328
# Name: count, dtype: int64

# %% [markdown]
# ## SQL CODE

# %%
select  Branch, count(*) from Supermarket group by Branch

# %% [markdown]
# ## 2) What is value count of Product_Line

# %% [markdown]
# ## Python CODE

# %%
df['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %% [markdown]
# ## SQL CODE

# %%
select  Product_line, count(*) as No_Product from Supermarket group by Product_line

# %% [markdown]
# ## 3) The highest Total per each Product

# %% [markdown]
# ## Python CODE

# %%
result=df.groupby('Product line')['Total'].max()
order= result.sort_values(ascending=False)
order
# Out:
# Product line
# Fashion accessories       1042.6500
# Food and beverages        1034.4600
# Home and lifestyle        1023.7500
# Sports and travel         1002.1200
# Health and beauty          950.2500
# Electronic accessories     942.4485
# Name: Total, dtype: float64

# %% [markdown]
# ## SQL CODE

# %%
select Product_line, max(Total) from Supermarket group by Product_line order by max(Total) DESC

# %% [markdown]
# ##4) The highest gross income per each Product

# %% [markdown]
# ## Python CODE

# %%
result=df.groupby('Product line')['gross income'].max()
order= result.sort_values(ascending=False)
order
# Out:
# Product line
# Fashion accessories       49.6500
# Food and beverages        49.2600
# Home and lifestyle        48.7500
# Sports and travel         47.7200
# Health and beauty         45.2500
# Electronic accessories    44.8785
# Name: gross income, dtype: float64

# %% [markdown]
# ## SQL CODE

# %%
select Product_line, max(gross_income) from Supermarket group by Product_line order by max(gross_income) DESC

# %% [markdown]
# ## 5) The highest Total per each Branch

# %% [markdown]
# ## Python CODE

# %%
result=df.groupby('Branch')['Total'].max()
order= result.sort_values(ascending=False)
order
# Out:
# Branch
# mamoura        1042.65
# Helioples      1039.29
# zouni beach    1022.49
# Name: Total, dtype: float64

# %% [markdown]
# ## SQL CODE

# %%
select Branch, max(Total) from Supermarket group by Branch order by max(Total) DESC

# %% [markdown]
# ## 6) The highest gross incom per each branch

# %%
result=df.groupby('Branch')['gross income'].max()
order= result.sort_values(ascending=False)
order
# Out:
# Branch
# mamoura        49.65
# Helioples      49.49
# zouni beach    48.69
# Name: gross income, dtype: float64

# %% [markdown]
# # SQL CODE

# %%
select Branch, max(gross_income) from Supermarket group by Branch order by max(gross_income) DESC

# %% [markdown]
# ## 7)The highest cost of goods per each Products

# %% [markdown]
# Python code

# %%
result=df.groupby('Product line')['cogs'].max()
order= result.sort_values(ascending=False)
order
# Out:
# Product line
# Fashion accessories       993.00
# Food and beverages        985.20
# Home and lifestyle        975.00
# Sports and travel         954.40
# Health and beauty         905.00
# Electronic accessories    897.57
# Name: cogs, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select Product_line, max(cogs) from Supermarket group by Product_line order by max(cogs) DESC

# %% [markdown]
# ## 8)The highest cost of goods per each Branch

# %% [markdown]
# ## Python code

# %%
result=df.groupby('Branch')['cogs'].max()
order= result.sort_values(ascending=False)
order
# Out:
# Branch
# mamoura        993.0
# Helioples      989.8
# zouni beach    973.8
# Name: cogs, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select Branch, max(cogs) from Supermarket group by Branch order by max(cogs) DESC

# %% [markdown]
# ## 9) Who had the highest Total

# %% [markdown]
# ## Python code

# %%
result=df.groupby(['Invoice ID','Date','Time'])['Total'].max()
order= result.sort_values(ascending=False).head(1)
order
# Out:
# Invoice ID   Date       Time
# 860-79-0874  2/15/2019  14:53    1042.65
# Name: Total, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select Invoice_ID,Date, Time, max(Total) from Supermarket group by Invoice_ID,Date,Time order by max(Total) DESC offset 0 rows fetch next 1 rows only
# Out:
# Invoice ID
# 860-79-0874    1042.65
# Name: Total, dtype: float64

# %% [markdown]
# ## 10) what is the city that got the highest Total

# %% [markdown]
# ## Python code

# %%
result=df.groupby(['City','Date','Time'])['Total'].max()
order= result.sort_values(ascending=False).head(1)
order
# Out:
# City  Date       Time
# Alex  2/15/2019  14:53    1042.65
# Name: Total, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select City,Date, Time, max(Total) from Supermarket group by City,Date,Time order by max(Total) DESC offset 0 rows fetch next 1 rows only

# %% [markdown]
# ##11) the max of (Total- gross income - gross precentage- rating- tax)

# %%
df[['Total','Tax 5%','gross margin percentage','gross income','Rating']].max()
# Out:
# Total                      1042.650000
# Tax 5%                       49.650000
# gross margin percentage       4.761905
# gross income                 49.650000
# Rating                       10.000000
# dtype: float64

# %% [markdown]
# ## SQL code

# %%
select max(Total) as max_total, max(Tax_5) as max_tax, max(gross_margin_percentage) as max_gmp, max(gross_income) as max_gross, max(Rating) as max_rating from Supermarket

# %% [markdown]
# ## 12) Count of invoice per each city

# %% [markdown]
# ## Python code

# %%
df.groupby("City")["Invoice ID"].count()
# Out:
# City
# Alex     328
# Cairo    340
# Gouna    332
# Name: Invoice ID, dtype: int64

# %% [markdown]
# ## SQL code

# %%
select City, count(Invoice_Id) from Supermarket group by City

# %% [markdown]
# ## 13) Nomber of invoice per each gender , customer type

# %% [markdown]
# ## Python code

# %%
df.groupby(['Gender', 'Customer type'])['Invoice ID'].count()
# Out:
# Gender  Customer type
# Female  Member           261
#         Normal           240
# Male    Member           240
#         Normal           259
# Name: Invoice ID, dtype: int64

# %% [markdown]
# ## SQL code

# %%
SELECT Gender ,Customer_type , COUNT(Invoice_ID) from supermarket GROUP BY Gender,Customer_type

# %% [markdown]
# ## 14) The average of gross income per each gender , customer type

# %%
df.groupby(['Customer type','Gender'])['gross income'].mean()
# Out:
# Customer type  Gender
# Member         Female    16.082274
#                Male      15.094544
# Normal         Female    15.820631
#                Male      14.526075
# Name: gross income, dtype: float64

# %%
SELECT Gender ,Customer_type , AVG(gross_income) from Supermarket GROUP BY Gender,Customer_type

# %% [markdown]
# ## 15) The sum Total per each Gender and Product

# %% [markdown]
# ## Python code

# %%
df.groupby(['Gender','Product line'])['Total'].sum()
# Out:
# Gender  Product line
# Female  Electronic accessories    27102.0225
#         Fashion accessories       30437.4000
#         Food and beverages        33170.9175
#         Health and beauty         18560.9865
#         Home and lifestyle        30036.8775
#         Sports and travel         28574.7210
# Male    Electronic accessories    27235.5090
#         Fashion accessories       23868.4950
#         Food and beverages        22973.9265
#         Health and beauty         30632.7525
#         Home and lifestyle        23825.0355
#         Sports and travel         26548.1055
# Name: Total, dtype: float64

# %% [markdown]
# ## SQL code

# %%
SELECT Gender, Product_line , sum(Total) from Supermarket GROUP BY Gender, Product_line

# %% [markdown]
# ## 16) The No Branch per gender

# %% [markdown]
# ## Python code

# %%
df.groupby(["Gender",'Branch'])["Gender"].count()
# Out:
# Gender  Branch
# Female  Helioples      161
#         mamoura        178
#         zouni beach    162
# Male    Helioples      179
#         mamoura        150
#         zouni beach    170
# Name: Gender, dtype: int64

# %% [markdown]
# ## SQL code

# %%
SELECT Gender,Branch, COUNT(Gender) from supermarket GROUP BY Gender,Branch

# %% [markdown]
# ## 17) The Sum and Average of Total Sales per city and gender

# %% [markdown]
# ### Python code

# %%
sales=df.groupby(['City','Gender'])['Total'].agg(['sum','mean'])
order= sales.sort_values(ascending= False, by='Gender')
order
# Out:
#                      sum        mean
# City  Gender
# Alex  Male    48883.2435  325.888290
# Cairo Male    52931.2035  295.705047
# Gouna Male    53269.3770  313.349276
# Alex  Female  61685.4630  346.547545
# Cairo Female  53269.1670  330.864391
# Gouna Female  52928.2950  326.717870

# %% [markdown]
# ## SQL code

# %%
select City,Gender, sum(Total) as sum_total, avg(Total)as avg_Total from Supermarket group by City, Gender order by Gender DESC

# %% [markdown]
# ##18) The Sum and Average of Total Sales per city and gender and customer type and product line

# %% [markdown]
# ## Python code

# %%
sales=df.groupby(['City','Customer type','Gender','Product line'])['Total'].agg(['max','sum','mean'])
order= sales.sort_values(ascending= False, by='Gender')
order
# Out:
#                                                         max        sum  \
# City  Customer type Gender Product line
# Gouna Normal        Male   Sports and travel        732.270  5848.0800
# Cairo Member        Male   Food and beverages       708.225  6048.9030
# Alex  Normal        Male   Sports and travel        937.818  1800.1095
# Gouna Member        Male   Sports and travel        944.622  4927.3035
#                            Home and lifestyle       633.990  2883.7620
# ...                                                     ...        ...
# Alex  Member        Female Fashion accessories     1042.650  7228.3155
# Cairo Normal        Female Fashion accessories      817.236  5644.8630
#                            Food and beverages       852.705  4171.6080
#                            Health and beauty        749.490  2520.5460
#                            Electronic accessories   836.304  6019.6605
#
#                                                          mean
# ...

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Gender,Product_line, max(Total)as max_total, sum(Total) as sum_total, avg(Total)as avg_Total from Supermarket group by City,Customer_type,Gender,Product_line order by Gender DESC

# %% [markdown]
# ## 19) The Top Rating per City, Customer type, Gender, product line

# %% [markdown]
# ## Python code

# %%
city_sales=df.groupby(['City','Customer type','Gender','Product line'])['Rating'].max()
order= city_sales.sort_values(ascending= False)
order
# Out:
# City   Customer type  Gender  Product line
# Gouna  Normal         Male    Sports and travel         10.0
# Alex   Member         Female  Sports and travel         10.0
# Gouna  Member         Female  Sports and travel         10.0
#        Normal         Female  Electronic accessories    10.0
# Cairo  Normal         Female  Health and beauty         10.0
#                                                         ...
# Alex   Normal         Male    Sports and travel          9.0
# Cairo  Normal         Female  Electronic accessories     9.0
# Alex   Normal         Female  Home and lifestyle         8.8
# Gouna  Normal         Male    Food and beverages         8.7
#        Member         Male    Home and lifestyle         7.7
# Name: Rating, Length: 72, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Gender,Product_line, max(Rating) as max_Rating from Supermarket group by City,Customer_type,Gender,Product_line order by Gender DESC

# %% [markdown]
# ## 20) The Top Quntity per city, customer type, gender , product lin

# %% [markdown]
# ## Python code

# %%
city_sales=df.groupby(['City','Customer type','Gender'])['Quantity'].sum()
order= city_sales.sort_values(ascending= False)
order
# Out:
# City   Customer type  Gender  Product line
# Alex   Member         Female  Electronic accessories    10
# Gouna  Member         Female  Food and beverages        10
# Cairo  Member         Male    Health and beauty         10
#                               Home and lifestyle        10
#                               Sports and travel         10
#                                                         ..
#        Normal         Male    Health and beauty          9
# Gouna  Normal         Female  Food and beverages         8
# Alex   Member         Male    Home and lifestyle         8
# Cairo  Normal         Female  Sports and travel          7
# Alex   Member         Male    Sports and travel          7
# Name: Quantity, Length: 72, dtype: int64

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Gender, sum(Quantity) as sum_Quantity from Supermarket group by City,Customer_type,Gender order by Gender DESC

# %% [markdown]
# ## 21) The Top Tax per city,custome, gender,product line

# %% [markdown]
# ## Python code

# %%
city_sales=df.groupby(['City','Customer type','Gender'])['Tax 5%'].max()
order= city_sales.sort_values(ascending= False)
order
# Out:
# City   Customer type  Gender  Product line
# Alex   Member         Female  Fashion accessories    49.6500
# Cairo  Normal         Male    Fashion accessories    49.4900
# Alex   Member         Female  Food and beverages     49.2600
#        Normal         Male    Home and lifestyle     48.7500
# Gouna  Normal         Female  Home and lifestyle     48.6900
#                                                       ...
#                               Food and beverages     25.2150
# Cairo  Normal         Male    Food and beverages     24.5130
#                       Female  Sports and travel      22.3700
# Gouna  Member         Male    Food and beverages     20.9475
# Alex   Member         Male    Sports and travel      20.4365
# Name: Tax 5%, Length: 72, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Gender, max(Tax_5) as max_Tax from Supermarket group by City,Customer_type,Gender order by Gender DESC

# %% [markdown]
# ## 22)The Top Total per city,custome, gender,product line

# %% [markdown]
# ## Python code

# %%
sales=df.groupby(['City','Customer type','Gender'])['Total'].sum()
order= sales.sort_values(ascending= False)
order
# Out:
# City   Customer type  Gender  Product line
# Alex   Member         Female  Fashion accessories    1042.6500
# Cairo  Normal         Male    Fashion accessories    1039.2900
# Alex   Member         Female  Food and beverages     1034.4600
#        Normal         Male    Home and lifestyle     1023.7500
# Gouna  Normal         Female  Home and lifestyle     1022.4900
#                                                        ...
#                               Food and beverages      529.5150
# Cairo  Normal         Male    Food and beverages      514.7730
#                       Female  Sports and travel       469.7700
# Gouna  Member         Male    Food and beverages      439.8975
# Alex   Member         Male    Sports and travel       429.1665
# Name: Total, Length: 72, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Gender,Product_line, sum(Total) as max_Total from Supermarket group by City,Customer_type,Gender order by Gender DESC

# %% [markdown]
# ##23) The Top Price per city,custome, gender,product lin

# %% [markdown]
# ## Python code

# %%
price=df.groupby(['City','Customer type','Gender'])['Unit price'].max()
order= price.sort_values(ascending= False)
order
# Out:
# City   Customer type  Gender  Product line
# Alex   Normal         Male    Health and beauty      99.96
# Gouna  Member         Male    Sports and travel      99.96
#        Normal         Male    Home and lifestyle     99.92
#                               Fashion accessories    99.89
# Cairo  Member         Male    Health and beauty      99.83
#                                                      ...
#        Normal         Female  Health and beauty      79.74
# Gouna  Member         Female  Health and beauty      76.90
# Alex   Normal         Female  Home and lifestyle     73.56
# Gouna  Normal         Male    Food and beverages     73.06
#        Member         Male    Home and lifestyle     71.86
# Name: Unit price, Length: 72, dtype: float64

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Gender, max(Unit_price) as max_price from Supermarket group by City,Customer_type,Gender order by Gender DESC

# %% [markdown]
# ## 24)The Top and sum Price and Quantity and tax and Total per City and customer and Gender and Product

# %% [markdown]
# ## Python code

# %%
price=df.groupby(['City','Customer type','Gender','Product line'])[['Unit price','Quantity','Tax 5%','Total']].agg(['sum','max'])
order= price.sort_values(ascending= False, by='Gender' and 'Product line'and 'City')
order
# Out:
#                                                   Unit price        Quantity  \
#                                                          sum    max      sum
# City  Customer type Gender Product line
# Gouna Normal        Male   Sports and travel         1160.38  97.74       99
#       Member        Male   Sports and travel          851.97  99.96       73
#                     Female Electronic accessories     618.71  93.96       76
#                            Fashion accessories        751.67  97.61       79
#                            Food and beverages        1037.95  98.79      117
# ...                                                      ...    ...      ...
# Alex  Normal        Male   Food and beverages         821.71  99.79       72
#                            Health and beauty          838.77  99.96       88
#                            Home and lifestyle         597.40  97.50       60
#                            Sports and travel          271.13  99.24       18
# ...

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Gender,Product_line, max(Unit_price) as max_price, sum(Unit_price) as sum_price,max(Quantity) as max_Quantity, sum(Quantity) as sum_Quantity,max(Tax_5) as max_Tax, sum(Tax_5) as sum_Tax,max(Total) as max_Total, sum(Total) as sum_Total from Supermarket group by City,Customer_type,Gender,Product_line order by Gender,Product_line,City DESC

# %% [markdown]
# ## 25) The Top and sum Price and Quantity and tax and Total and Payment per City and customer  and Product

# %%
price=df.groupby(['City','Customer type','Product line'])[['Unit price','Quantity','Tax 5%','Total','Payment']].agg(['sum','max'])
order= price.sort_values(ascending= False, by='Paymetn' and 'Product line'and 'City')
order
# Out:
#                                            Unit price        Quantity      \
#                                                   sum    max      sum max
# City  Customer type Product line
# Gouna Normal        Sports and travel         1830.01  97.74      157  10
#       Member        Sports and travel         1870.03  99.96      165  10
#                     Electronic accessories    1308.59  93.96      147  10
#                     Fashion accessories       1669.69  97.61      143  10
#                     Food and beverages        1622.39  98.79      160  10
#                     Health and beauty         1531.25  97.22      172  10
#                     Home and lifestyle        1130.72  94.59      137  10
#       Normal        Electronic accessories    1433.39  99.73      169  10
#                     Fashion accessories       1730.63  99.89      154  10
#                     Food and beverages        1154.61  99.69      110  10
# ...

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Product_line,Payment, max(Unit_price) as max_price, sum(Unit_price) as sum_price,max(Quantity) as max_Quantity, sum(Quantity) as sum_Quantity,max(Tax_5) as max_Tax, sum(Tax_5) as sum_Tax,max(Total) as max_Total, sum(Total) as sum_Total from Supermarket group by City,Customer_type,Product_line,Payment order by Product_line,City,Payment DESC

# %% [markdown]
# ## 26) the Average and sum gross margin and gross income per each city, custome, product, date, paymen

# %% [markdown]
# ## Python code

# %%
city_sales=df.groupby(['City','Customer type','Product line','Date','Payment'])[['gross margin percentage','gross income']].agg(['sum','max'])
order= city_sales.sort_values(ascending= True, by='Paymetn' and 'Product line'and 'City' and 'Date')
order
# Out:
#                                                                 gross margin percentage  \
#                                                                                     sum
# City  Customer type Product line           Date     Payment
# Alex  Member        Sports and travel      1/1/2019 Credit card                4.761905
# Cairo Normal        Sports and travel      1/1/2019 Credit card                4.761905
# Alex  Member        Sports and travel      1/1/2019 Ewallet                    4.761905
# Cairo Normal        Fashion accessories    1/1/2019 Cash                       4.761905
# Gouna Normal        Food and beverages     1/1/2019 Cash                       4.761905
# ...                                                                                 ...
# Cairo Normal        Health and beauty      3/9/2019 Credit card                4.761905
#                     Fashion accessories    3/9/2019 Credit card                4.761905
# ...

# %% [markdown]
# ## SQL code

# %%
select City,Customer_type,Product_line, Date,Payment, sum(gross_margin_percentage) as sum_grossmp, avg(gross_margin_percentage) as avg_grossmp,sum(gross_income) as sum_gross, avg(gross_income) as avg_gross  from Supermarket  group by City,Customer_type,Product_line,Date,Payment order by Date ASC

# %% [markdown]
# ## 27) The Top Rating per each gender, product, payment

# %%
rating=df.groupby(['Gender','Product line','Payment'])[['Rating',"Total",'gross margin percentage','gross income']].max()
order= rating.sort_values(ascending= False, by='Gender' and 'Product line'and 'Payment')
order
# Out:
#                                            Rating      Total  \
# Gender Product line           Payment
# Male   Sports and travel      Ewallet        10.0   937.8180
#        Home and lifestyle     Ewallet         9.9  1023.7500
#        Fashion accessories    Ewallet         9.7   829.0800
#        Health and beauty      Ewallet         9.9   922.6350
#        Electronic accessories Ewallet         9.9   931.0350
# Female Sports and travel      Ewallet        10.0   921.1860
#        Home and lifestyle     Ewallet         9.8  1022.4900
#        Health and beauty      Ewallet         9.2   628.1730
# Male   Food and beverages     Ewallet         9.6   814.3800
# Female Food and beverages     Ewallet         9.9  1034.4600
#        Electronic accessories Ewallet        10.0   771.4350
#        Fashion accessories    Ewallet         9.9   867.6150
# Male   Electronic accessories Credit card     9.9   757.3650
#        Food and beverages     Credit card     9.6   939.5400
# ...

# %% [markdown]
# ## SQL code

# %%
select Gender,Product_line,Payment, max(Rating) as max_Rating, max(Total) as max_Total, max(gross_margin_percentage) as sum_grossmp, max(gross_income) as max_gross  from Supermarket  group by Gender,Product_line,Payment order by Gender, Product_line, Payment ASC

# %% [markdown]
# # 28) The Top Quantity,Total, grossmargin, gross income per each gender, product, payment

# %%
quantity=df.groupby(['Gender','Product line','Payment'])[['Quantity',"Total",'gross margin percentage','gross income']].max()
order= quantity.sort_values(ascending= False, by='Gender' and 'Product line'and 'Payment')
order
# Out:
#                                            Quantity      Total  \
# Gender Product line           Payment
# Male   Sports and travel      Ewallet            10   937.8180
#        Home and lifestyle     Ewallet            10  1023.7500
#        Fashion accessories    Ewallet            10   829.0800
#        Health and beauty      Ewallet            10   922.6350
#        Electronic accessories Ewallet            10   931.0350
# Female Sports and travel      Ewallet            10   921.1860
#        Home and lifestyle     Ewallet            10  1022.4900
#        Health and beauty      Ewallet             9   628.1730
# Male   Food and beverages     Ewallet            10   814.3800
# Female Food and beverages     Ewallet            10  1034.4600
#        Electronic accessories Ewallet            10   771.4350
#        Fashion accessories    Ewallet            10   867.6150
# Male   Electronic accessories Credit card        10   757.3650
# ...

# %% [markdown]
# # SQL code

# %%
select Gender,Product_line,Payment, max(Quantity) as max_Qauntity, max(Total) as max_Total, max(gross_margin_percentage) as sum_grossmp, max(gross_income) as max_gross  from Supermarket  group by Gender,Product_line,Payment order by Gender, Product_line, Payment ASC

# %%
df.to_csv('SupermarketG1.csv', index=False)

# %%
df[(df['Product line']=='Health and beauty') & (df['Gender']== 'Female')]
# Out:
#      Unnamed: 0   Invoice ID       Branch   City Customer type  Gender  \
# 0             0  750-67-8428    Helioples  Cairo        Member  Female
# 8             8  665-32-9167    Helioples  Cairo        Member  Female
# 14           14  829-34-3910    Helioples  Cairo        Normal  Female
# 16           16  656-95-9349    Helioples  Cairo        Member  Female
# 38           38  333-73-7901      mamoura   Alex        Normal  Female
# ..          ...          ...          ...    ...           ...     ...
# 927         927  397-25-8725    Helioples  Cairo        Member  Female
# 936         936  433-08-7822      mamoura   Alex        Normal  Female
# 938         938  131-70-8179    Helioples  Cairo        Member  Female
# 968         968  605-03-2706    Helioples  Cairo        Normal  Female
# 986         986  764-44-8999  zouni beach  Gouna        Normal  Female
#
#           Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# ...

# %% [markdown]
# Pivot Table

# %% [markdown]
# ![ex1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ex2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ex3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ex4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ex5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ex6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ex7.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## Power Bi

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![7.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![8.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![9.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![10.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![11.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![12.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![13.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![14.JPG](data:image/jpeg;base64,...)
